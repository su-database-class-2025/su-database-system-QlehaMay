# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# 2019年4月の休日昼間人口を地図化する

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='geom') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = "SELECT p.name, d.prefcode, d.year, d.month, d.population, p.geom \
        FROM pop AS d \
            INNER JOIN pop_mesh AS p \
                ON p.name = d.mesh1kmid \
            WHERE d.dayflag='0' AND \
                d.timezone='0' AND \
                d.year='2019' AND \
                d.month='04'"

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    m = folium.Map(location=[36, 139.5], zoom_start=8)

    # Add the choropleth layer
    folium.Choropleth(
        geo_data=gdf.to_json(),
        data=gdf,
        columns=['name', 'population'],
        key_on='feature.properties.name',
        fill_color='YlOrRd',
        fill_opacity=0.7,
        line_opacity=0,
        bins=[0, 1000, 5000, 10000, 25000, 50000, 75000, 100000, 140000]
    ).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
print(out)

map_display = display_interactive_map(out)

display(map_display)
# Out:
#            name prefcode  year month  population  \
# 0      53404026       12  2019    04      4244.0
# 1      53402099       12  2019    04      6745.0
# 2      53403115       12  2019    04       416.0
# 3      53403136       12  2019    04       653.0
# 4      53403074       12  2019    04      4310.0
# ...         ...      ...   ...   ...         ...
# 22651  53395421       13  2019    04     15711.0
# 22652  53394399       13  2019    04      6431.0
# 22653  53395225       13  2019    04      2496.0
# 22654  53394473       13  2019    04     19922.0
# 22655  52391313       13  2019    04        12.0
#
#                                                     geom
# 0      MULTIPOLYGON (((140.075 35.68333, 140.075 35.6...
# 1      MULTIPOLYGON (((140.1125 35.575, 140.1125 35.5...
# 2      MULTIPOLYGON (((140.1875 35.59167, 140.1875 35...
# 3      MULTIPOLYGON (((140.2 35.60833, 140.2 35.61667...
# 4      MULTIPOLYGON (((140.05 35.64167, 140.05 35.65,...
# ...                                                  ...
# 22651  MULTIPOLYGON (((139.5125 35.76667, 139.5125 35...
# 22652  MULTIPOLYGON (((139.4875 35.74167, 139.4875 35...
# 22653  MULTIPOLYGON (((139.3125 35.76667, 139.3125 35...
# 22654  MULTIPOLYGON (((139.5375 35.725, 139.5375 35.7...
# 22655  MULTIPOLYGON (((139.4125 34.75833, 139.4125 34...
#
# [22656 rows x 6 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_51618/341514070.py in ?()
#       1 out = query_geopandas(sql,'gisdb')
#       2 print(out)
#       3
# ----> 4 map_display = display_interactive_map(out)
#       5
#       6 display(map_display)
#
# /tmp/ipykernel_51618/1086924296.py in ?(gdf)
#       1 def display_interactive_map(gdf):
#       2     m = folium.Map(location=[36, 139.5], zoom_start=8)
#       3
#       4     # Add the choropleth layer
# ----> 5     folium.Choropleth(
#       6         geo_data=gdf.to_json(),
#       7         data=gdf,
#       8         columns=['city', 'population'],
#
# /usr/local/lib/python3.11/site-packages/folium/features.py in ?(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, use_jenks, **kwargs)
#    1542         # Create color_data dict
#    1543         if hasattr(data, "set_index"):
#    1544             # This is a pd.DataFrame
#    1545             assert columns is not None
# -> 1546             color_data = data.set_index(columns[0])[columns[1]].to_dict()  # type: ignore
#    1547         elif hasattr(data, "to_dict"):
#    1548             # This is a pd.Series
#    1549             color_data = data.to_dict()  # type: ignore
#
# /usr/local/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['city'] are in the columns"
