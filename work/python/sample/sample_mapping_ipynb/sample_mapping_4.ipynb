# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# さいたま市内のコンビニを抽出し地図化する

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.shop='driving_school' and
    poly.name_2='Saitama' and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 out = query_geopandas(sql,'gisdb')
# ----> 2 map_display = display_interactive_map(out)
#       3 print(out)
#       4 display(map_display)
#
# Cell In[4], line 3, in display_interactive_map(gdf)
#       1 def display_interactive_map(gdf):
#       2     if gdf.crs != 'EPSG:4326':
# ----> 3         gdf = gdf.to_crs(epsg=4326)
#       4     # Create a base map
#       5     m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset
#
# File /usr/local/lib/python3.11/site-packages/geopandas/geodataframe.py:1861, in GeoDataFrame.to_crs(self, crs, epsg, inplace)
#    1859 else:
#    1860     df = self.copy()
# -> 1861 geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#    1862 df.geometry = geom
#    1863 if not inplace:
#
# File /usr/local/lib/python3.11/site-packages/geopandas/geoseries.py:1271, in GeoSeries.to_crs(self, crs, epsg)
#    1194 def to_crs(self, crs: Any | None = None, epsg: int | None = None) -> GeoSeries:
#    1195     """Returns a ``GeoSeries`` with all geometries transformed to a new
#    1196     coordinate reference system.
#    1197
#    (...)   1268
#    1269     """
#    1270     return GeoSeries(
# -> 1271         self.values.to_crs(crs=crs, epsg=epsg), index=self.index, name=self.name
#    1272     )
#
# File /usr/local/lib/python3.11/site-packages/geopandas/_compat.py:84, in requires_pyproj.<locals>.wrapper(*args, **kwargs)
#      78 if not HAS_PYPROJ:
#      79     raise ImportError(
#      80         f"The 'pyproj' package is required for {func.__name__} to work. "
#      81         "Install it and initialize the object with a CRS before using it."
#      82         f"\nImporting pyproj resulted in: {pyproj_import_error}"
#      83     )
# ---> 84 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/geopandas/array.py:1094, in GeometryArray.to_crs(self, crs, epsg)
#    1091 from pyproj import CRS
#    1093 if self.crs is None:
# -> 1094     raise ValueError(
#    1095         "Cannot transform naive geometries.  "
#    1096         "Please set a crs on the object first."
#    1097     )
#    1098 if crs is not None:
#    1099     crs = CRS.from_user_input(crs)
#
# ValueError: Cannot transform naive geometries.  Please set a crs on the object first.
