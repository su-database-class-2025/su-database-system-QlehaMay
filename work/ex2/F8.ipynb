# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# （自由課題１）OpenStreetMapのデータを用いたテーマを自由に設定し、データを抽出し、結果を地図で示せ

# %% [markdown]
# 埼玉県内の赤ちゃん用品を売るお店をテーマに設定して場所を地図に示した

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.shop='baby_goods' and
    poly.name_2='Saitama' and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#        osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0  8567860003   None           None             None               None
# 1  6719001399   None           None             None               None
# 2  6055246466   None           None             None               None
# 3   260547818   None           None             None               None
# 4  7835812104   None           None             None               None
# 5  6876061838   None           None             None               None
# 6  8401358140   None           None             None               None
#
#   admin_level aerialway aeroway amenity  area barrier bicycle brand bridge  \
# 0        None      None    None    None  None    None    None  None   None
# 1        None      None    None    None  None    None    None   西松屋   None
# 2        None      None    None    None  None    None    None   西松屋   None
# 3        None      None    None    None  None    None    None  None   None
# 4        None      None    None    None  None    None    None   西松屋   None
# 5        None      None    None    None  None    None    None   西松屋   None
# 6        None      None    None    None  None    None    None   西松屋   None
#
#   boundary building capital construction covered culvert cutting denomination  \
# 0     None     None    None         None    None    None    None         None
# 1     None     None    None         None    None    None    None         None
# 2     None     None    None         None    None    None    None         None
# 3     None     None    None         None    None    None    None         None
# 4     None     None    None         None    None    None    None         None
# 5     None     None    None         None    None    None    None         None
# 6     None     None    None         None    None    None    None         None
#
#   disused   ele embankment  foot generator:source harbour highway historic  \
# 0    None  None       None  None             None    None    None     None
# 1    None  None       None  None             None    None    None     None
# 2    None  None       None  None             None    None    None     None
# 3    None  None       None  None             None    None    None     None
# 4    None  None       None  None             None    None    None     None
# 5    None  None       None  None             None    None    None     None
# 6    None  None       None  None             None    None    None     None
#
#   horse intermittent junction landuse layer leisure  lock man_made military  \
# 0  None         None     None    None  None    None  None     None     None
# 1  None         None     None    None  None    None  None     None     None
# 2  None         None     None    None  None    None  None     None     None
# 3  None         None     None    None  None    None  None     None     None
# 4  None         None     None    None  None    None  None     None     None
# 5  None         None     None    None  None    None  None     None     None
# 6  None         None     None    None  None    None  None     None     None
#
#   motorcar             name natural office oneway operator place   poi  \
# 0     None            バースデイ    None   None   None     None  None  None
# 1     None              西松屋    None   None   None     None  None  None
# 2     None              西松屋    None   None   None     None  None  None
# 3     None            バースデイ    None   None   None     None  None  None
# 4     None              西松屋    None   None   None     None  None  None
# 5     None              西松屋    None   None   None     None  None  None
# 6     None  西松屋 オリンピック武蔵浦和店    None   None   None     None  None  None
#
#   population power power_source public_transport railway   ref religion route  \
# 0       None  None         None             None    None  None     None  None
# 1       None  None         None             None    None  None     None  None
# 2       None  None         None             None    None  None     None  None
# 3       None  None         None             None    None  None     None  None
# 4       None  None         None             None    None  None     None  None
# 5       None  None         None             None    None  None     None  None
# 6       None  None         None             None    None  None     None  None
#
#   service        shop sport surface  toll tourism tower:type tunnel water  \
# 0    None  baby_goods  None    None  None    None       None   None  None
# 1    None  baby_goods  None    None  None    None       None   None  None
# 2    None  baby_goods  None    None  None    None       None   None  None
# 3    None  baby_goods  None    None  None    None       None   None  None
# 4    None  baby_goods  None    None  None    None       None   None  None
# 5    None  baby_goods  None    None  None    None       None   None  None
# 6    None  baby_goods  None    None  None    None       None   None  None
#
#   waterway wetland width  wood z_order                               way
# 0     None    None  None  None    None  POINT (15544244.328 4285826.163)
# 1     None    None  None  None    None  POINT (15555191.097 4286567.412)
# 2     None    None  None  None    None   POINT (15541905.238 4286021.66)
# 3     None    None  None  None    None  POINT (15542748.617 4291857.865)
# 4     None    None  None  None    None  POINT (15543357.223 4282743.092)
# 5     None    None  None  None    None  POINT (15550691.485 4283666.273)
# 6     None    None  None  None    None  POINT (15545522.799 4279586.267)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c73824f2dc3d485f3cd7cd8591046384 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c73824f2dc3d485f3cd7cd8591046384&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c73824f2dc3d485f3cd7cd8591046384 = L.map(
#                 &quot;map_c73824f2dc3d485f3cd7cd8591046384&quot;,
#                 {
#                     center: [35.8616, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0bdb8a03846e66e7dc5daaf4556a0d0b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0bdb8a03846e66e7dc5daaf4556a0d0b.addTo(map_c73824f2dc3d485f3cd7cd8591046384);
#
#
#             var marker_ffe2b6bb26ee2d2da235efb41def49eb = L.marker(
#                 [35.892402199725005, 139.6363226],
#                 {
# }
#             ).addTo(map_c73824f2dc3d485f3cd7cd8591046384);
#
#
#         var popup_e85c7e91e1ad6f614a67730913e87ebf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a141e233e7cb1c3f51b4fa07a401acf8 = $(`&lt;div id=&quot;html_a141e233e7cb1c3f51b4fa07a401acf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;バースデイ&lt;/div&gt;`)[0];
#                 popup_e85c7e91e1ad6f614a67730913e87ebf.setContent(html_a141e233e7cb1c3f51b4fa07a401acf8);
#
#
#
#         marker_ffe2b6bb26ee2d2da235efb41def49eb.bindPopup(popup_e85c7e91e1ad6f614a67730913e87ebf)
#         ;
#
#
#
#
#             var marker_13e9bfad7de6f68cd774d2685a95fbfd = L.marker(
#                 [35.89779639972552, 139.7346591],
#                 {
# }
#             ).addTo(map_c73824f2dc3d485f3cd7cd8591046384);
#
#
#         var popup_6a01a069e2a7fe3a6a411e8f774373cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_465874a9dcd672bcd9f5efd249a8cd97 = $(`&lt;div id=&quot;html_465874a9dcd672bcd9f5efd249a8cd97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;西松屋&lt;/div&gt;`)[0];
#                 popup_6a01a069e2a7fe3a6a411e8f774373cd.setContent(html_465874a9dcd672bcd9f5efd249a8cd97);
#
#
#
#         marker_13e9bfad7de6f68cd774d2685a95fbfd.bindPopup(popup_6a01a069e2a7fe3a6a411e8f774373cd)
#         ;
#
#
#
#
#             var marker_9777a85fda1ce21297577a9af2262fb8 = L.marker(
#                 [35.89382489972514, 139.6153102],
#                 {
# }
#             ).addTo(map_c73824f2dc3d485f3cd7cd8591046384);
#
#
#         var popup_b3b7751a56f9df8c5e0211f03151ac80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e707f245417b886524e7bd0f30a52e0 = $(`&lt;div id=&quot;html_7e707f245417b886524e7bd0f30a52e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;西松屋&lt;/div&gt;`)[0];
#                 popup_b3b7751a56f9df8c5e0211f03151ac80.setContent(html_7e707f245417b886524e7bd0f30a52e0);
#
#
#
#         marker_9777a85fda1ce21297577a9af2262fb8.bindPopup(popup_b3b7751a56f9df8c5e0211f03151ac80)
#         ;
#
#
#
#
#             var marker_1b1a76d16dd625f539d1fe33f7c664a6 = L.marker(
#                 [35.93628529972926, 139.6228864],
#                 {
# }
#             ).addTo(map_c73824f2dc3d485f3cd7cd8591046384);
#
#
#         var popup_c0962f36025506fc0362573f7f9b53af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_633fbeff44156affc70bb9798183596e = $(`&lt;div id=&quot;html_633fbeff44156affc70bb9798183596e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;バースデイ&lt;/div&gt;`)[0];
#                 popup_c0962f36025506fc0362573f7f9b53af.setContent(html_633fbeff44156affc70bb9798183596e);
#
#
#
#         marker_1b1a76d16dd625f539d1fe33f7c664a6.bindPopup(popup_c0962f36025506fc0362573f7f9b53af)
#         ;
#
#
#
#
#             var marker_ca9820400fb0cc57af1f4a543391f9dd = L.marker(
#                 [35.869962199722856, 139.62835359999997],
#                 {
# }
#             ).addTo(map_c73824f2dc3d485f3cd7cd8591046384);
#
#
#         var popup_18e5eea69a88a68e70ac73c973042b63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77d222d3ebd7e34d5508ec6ba7d1d778 = $(`&lt;div id=&quot;html_77d222d3ebd7e34d5508ec6ba7d1d778&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;西松屋&lt;/div&gt;`)[0];
#                 popup_18e5eea69a88a68e70ac73c973042b63.setContent(html_77d222d3ebd7e34d5508ec6ba7d1d778);
#
#
#
#         marker_ca9820400fb0cc57af1f4a543391f9dd.bindPopup(popup_18e5eea69a88a68e70ac73c973042b63)
#         ;
#
#
#
#
#             var marker_392a1c8f01ebbbd87acff581c61d86af = L.marker(
#                 [35.8766821997235, 139.694238
